# %%
import pandas as pd
from langchain.document_loaders import UnstructuredPDFLoader
from langchain.indexes import VectorstoreIndexCreator
from langchain.callbacks import get_openai_callback
import os

# Set environment variables
os.environ["LANGCHAIN_TRACING"] = "true"
os.environ["LANGCHAIN_SESSION"] = "pdf_query"
os.environ["OPENAI_API_KEY"] = "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"

# Load resume data
pdf_folder_path = "data/"
loader = [UnstructuredPDFLoader(os.path.join(pdf_folder_path, fn)) for fn in os.listdir(pdf_folder_path)]

# %%
# Create skill matrix
with get_openai_callback() as cb:
    index = VectorstoreIndexCreator().from_loaders(loader).index

    skill_matrix = pd.DataFrame(columns=["Requirements and Skills", "Match"])

    # Add JD skills to the skill matrix
    jd_skills = [
        "Python and associated frameworks such as Django and Flask",
        "Python's multi-process architecture and threading restrictions",
        "Server-side templating languages such as Jinja 2 and Mako",
        "Integration of many data sources into a single system",
        "Collaboration on projects and ability to work independently",
        "Ability to test Python programs successfully",
        "Excellent communication and teamwork abilities",
        "Knowledge of front-end technology like JavaScript and HTML5",
        "Excellent problem-solving abilities",
        "Bachelor of Science in Computer Science, Engineering, or a related discipline",
        "Understanding of front-end technologies such as JavaScript, HTML5, and CSS3",
        "Knowledge of some ORM (Object Relational Mapper) libraries",
        "Combining multiple data sources and databases into a single system",
        "User authentication and authorization knowledge across systems, servers, and environments"
    ]
    skill_matrix["Requirements and Skills"] = jd_skills

    # Check resume skills against JD skills
    for doc_id in index.document_ids:
        doc = index.document_by_id(doc_id)
        resume_skills = doc.metadata["skills"]
        match_skills = []
        for skill in jd_skills:
            if any(keyword.lower() in skill.lower() for keyword in resume_skills):
                match_skills.append("Yes")
            else:
                match_skills.append("No")
        skill_matrix[doc.metadata["filename"]] = match_skills

    print(skill_matrix)
    print(cb)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Create skill matrix
#       2 with get_openai_callback() as cb:
# ----> 3     index = VectorstoreIndexCreator().from_loaders(loader).index
#       5     skill_matrix = pd.DataFrame(columns=["Requirements and Skills", "Match"])
#       7     # Add JD skills to the skill matrix
#
# AttributeError: 'VectorStoreIndexWrapper' object has no attribute 'index'

# %%
import pandas as pd
from langchain.document_loaders import UnstructuredPDFLoader
from langchain.indexes import VectorstoreIndexCreator
from langchain.callbacks import get_openai_callback
import os

# Set environment variables
os.environ["LANGCHAIN_TRACING"] = "true"
os.environ["LANGCHAIN_SESSION"] = "pdf_query"
os.environ["OPENAI_API_KEY"] = "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"

# Load resume data
pdf_folder_path = "data/"
loader = [UnstructuredPDFLoader(os.path.join(pdf_folder_path, fn)) for fn in os.listdir(pdf_folder_path)]

# Create skill matrix
with get_openai_callback() as cb:
    index = VectorstoreIndexCreator().from_loaders(loader)

    skill_matrix = pd.DataFrame(columns=["Requirements and Skills", "Match"])

    # Add JD skills to the skill matrix
    jd_skills = [
        "Python and associated frameworks such as Django and Flask",
        "Python's multi-process architecture and threading restrictions",
        "Server-side templating languages such as Jinja 2 and Mako",
        "Integration of many data sources into a single system",
        "Collaboration on projects and ability to work independently",
        "Ability to test Python programs successfully",
        "Excellent communication and teamwork abilities",
        "Knowledge of front-end technology like JavaScript and HTML5",
        "Excellent problem-solving abilities",
        "Bachelor of Science in Computer Science, Engineering, or a related discipline",
        "Understanding of front-end technologies such as JavaScript, HTML5, and CSS3",
        "Knowledge of some ORM (Object Relational Mapper) libraries",
        "Combining multiple data sources and databases into a single system",
        "User authentication and authorization knowledge across systems, servers, and environments"
    ]
    skill_matrix["Requirements and Skills"] = jd_skills

    # Check resume skills against JD skills
    for doc in index.documents:
        resume_skills = doc.metadata["skills"]
        match_skills = []
        for skill in jd_skills:
            if any(keyword.lower() in skill.lower() for keyword in resume_skills):
                match_skills.append("Yes")
            else:
                match_skills.append("No")
        skill_matrix[doc.metadata["filename"]] = match_skills

    print(skill_matrix)
    print(cb)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 42
#      39 skill_matrix["Requirements and Skills"] = jd_skills
#      41 # Check resume skills against JD skills
# ---> 42 for doc in index.documents:
#      43     resume_skills = doc.metadata["skills"]
#      44     match_skills = []
#
# AttributeError: 'VectorStoreIndexWrapper' object has no attribute 'documents'

# %%
import pandas as pd
from langchain.document_loaders import UnstructuredPDFLoader
from langchain.indexes import VectorstoreIndexCreator
from langchain.callbacks import get_openai_callback
import os

# Set environment variables
os.environ["LANGCHAIN_TRACING"] = "true"
os.environ["LANGCHAIN_SESSION"] = "pdf_query"
os.environ["OPENAI_API_KEY"] = "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"

# Load resume data
pdf_folder_path = "data/"
loader = [UnstructuredPDFLoader(os.path.join(pdf_folder_path, fn)) for fn in os.listdir(pdf_folder_path)]

# Create skill matrix
with get_openai_callback() as cb:
    index = VectorstoreIndexCreator().from_loaders(loader)
 

    skill_matrix = pd.DataFrame(columns=["Requirements and Skills", "Match"])

    # Add JD skills to the skill matrix
    jd_skills = [
        "Python and associated frameworks such as Django and Flask",
        "Python's multi-process architecture and threading restrictions",
        "Server-side templating languages such as Jinja 2 and Mako",
        "Integration of many data sources into a single system",
        "Collaboration on projects and ability to work independently",
        "Ability to test Python programs successfully",
        "Excellent communication and teamwork abilities",
        "Knowledge of front-end technology like JavaScript and HTML5",
        "Excellent problem-solving abilities",
        "Bachelor of Science in Computer Science, Engineering, or a related discipline",
        "Understanding of front-end technologies such as JavaScript, HTML5, and CSS3",
        "Knowledge of some ORM (Object Relational Mapper) libraries",
        "Combining multiple data sources and databases into a single system",
        "User authentication and authorization knowledge across systems, servers, and environments"
    ]
    skill_matrix["Requirements and Skills"] = jd_skills

    # Check resume skills against JD skills
    
    print(cb)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 43
#      40 skill_matrix["Requirements and Skills"] = jd_skills
#      42 # Check resume skills against JD skills
# ---> 43 for doc_id in index.document_ids:
#      44     doc = index.document_by_id(doc_id)
#      45     resume_skills = doc.metadata["skills"]
#
# AttributeError: 'VectorStoreIndexWrapper' object has no attribute 'document_ids'

# %%
import pandas as pd

# Define the skills and requirements from the job description
skills = [
    "Python and associated frameworks such as Django and Flask",
    "Comprehensive knowledge of Python's multi-process architecture and threading restrictions",
    "Knowledge of server-side templating languages such as Jinja 2 and Mako",
    "Understanding of integration of many data sources into a single system",
    "Ability to work collaboratively on projects as well as independently when necessary",
    "Quick learner with the capacity to modify approaches dependent on the situation",
    "Awareness of how to test Python programs successfully",
    "Excellent communication and teamwork abilities",
    "Knowledge of front-end technology like JavaScript and HTML5",
    "Excellent problem-solving abilities",
    "Bachelor of Science in Computer Science, Engineering, or a related discipline",
    "Understanding of front-end technologies such as JavaScript, HTML5, and CSS3",
    "Knowledge of some ORM (Object Relational Mapper) libraries",
    "Capable of combining many data sources and databases into a single system",
    "User authentication and authorization knowledge across many systems, servers, and environments"
]

# Create a DataFrame for the skill matrix
skill_matrix = pd.DataFrame(columns=["Name"] + skills)

# Iterate through the resumes or candidates' profiles
for candidate in candidates:
    # Get the candidate's name
    name = candidate["Name"]
    
    # Initialize a row for the candidate in the skill matrix
    row = {"Name": name}
    
    # Check if the candidate possesses each skill
    for skill in skills:
        if skill in candidate["Skills"]:
            row[skill] = "Yes"
        else:
            row[skill] = "No"
    
    # Add the row to the skill matrix
    skill_matrix = skill_matrix.append(row, ignore_index=True)

# Calculate the overall score or rating for each candidate
# You can customize this calculation based on your requirements

# Display the skill matrix
print(skill_matrix)
# Out:
#   Cell In[10], line 30
#     row = {"Name": 'name'}
#     ^
# IndentationError: unexpected indent

# %%
import pandas as pd

# Job description summary
summary = """We're seeking talented Junior Python Engineers to become part of our team! Our Junior Python Developer wears multiple hats on their projects and is responsible for building and maintaining Python applications and interacting with other developers, designers, and stakeholders. They must have the skills to write a plethora of unit tests for code functionality. Good collaboration and communication skills are required to work with experienced engineers. In-depth knowledge of object-relational mapping, server-side logic, and above-average Python programming skills are expected. The responsibilities include Python application development, testing, maintenance, troubleshooting, code debugging, code documentation, code reviews, staying updated on emerging technologies, using server-side logic for user-facing aspects, prioritizing client feature requests, blending data storage options, coordinating with front-end developers, optimizing databases, creating digital technologies to track web traffic, improving responsiveness and overall performance, enhancing existing systems, and deploying data security and protection solutions. The required skills encompass expertise in Python and associated frameworks like Django and Flask, comprehensive knowledge of Python's multi-process architecture and threading restrictions, familiarity with server-side templating languages like Jinja 2 and Mako, understanding of integrating multiple data sources, ability to work collaboratively and independently, quick learning and adaptability, successful Python program testing, excellent communication and teamwork abilities, knowledge of front-end technology including JavaScript and HTML5, exceptional problem-solving skills, a Bachelor of Science degree in Computer Science, Engineering, or a related discipline, understanding of front-end technologies like JavaScript, HTML5, and CSS3, knowledge of some ORM libraries, and user authentication and authorization knowledge across systems, servers, and environments."""

# Create a pandas DataFrame
data = {
    "Work Name": ["Junior Python Engineer"],
    "Location": ["Your Company's Location"],
    "Experience": ["0-2 years"],
    "Skills": ["Python, Django, Flask, Python unit testing, collaboration, communication, object-relational mapping, server-side logic, Python programming, code documentation, code reviews, emerging technologies, server-side logic, data blending, front-end coordination, database optimization, web traffic tracking, performance improvement, system enhancement, data security"],
    "Post": ["Full-time"]
}

df = pd.DataFrame(data)

# Print the DataFrame
print(df)
# Out:
#                 Work Name                 Location Experience  \
# 0  Junior Python Engineer  Your Company's Location  0-2 years
#
#                                               Skills       Post
# 0  Python, Django, Flask, Python unit testing, co...  Full-time

# %%
import pandas as pd

# Define the job description
job_description = """
We're seeking talented Junior Python Engineers to become part of our team!! Our Junior Python Developer wears multiple hats on their projects and is responsible for building and maintaining Python applications and interacting with other developers, designers, and stakeholders on their projects.

You must have the skills to write a plethora of unit tests for your code to guarantee all functionality is being achieved. You will need good collaboration and communication skills as you will be spending a lot of time with experienced engineers and understanding how they do their jobs. Moreover, should have in-depth knowledge of object-relational mapping, familiarity with server-side logic, and above-average Python programming skills.

Roles and Responsibilities:
- Python application development, testing, and maintenance
- Working with other developers, designers, and stakeholders to satisfy project needs
- Troubleshooting and code debugging
- Developing and maintaining code and application documentation
- Participating in code reviews and contributing to best practices for the team
- Maintaining current knowledge of emerging technologies, programming languages, and software development techniques
- Using server-side logic to integrate user-facing aspects
- Ensuring client feature requests are being evaluated and prioritized
- Blending data storage options together
- Coordinating with front-end developers
- Optimising existing databases reprogrammed to increase functionality
- Creating digital technologies to track web traffic
- Improve responsiveness and overall performance by developing back-end components
- Enhance the functionality of existing systems
- Deploy data security and protection solutions

Requirements and Skills:
- Expertise in Python and associated frameworks such as Django and Flask
- Comprehensive knowledge of Python's multi-process architecture and threading restrictions
- Knowledge of server-side templating languages such as Jinja 2 and Mako
- Understanding of integration of many data sources into a single system
- Ability to work collaboratively on projects as well as independently when necessary
- Quick learner with the capacity to modify approaches dependent on the situation
- Awareness of how to test Python programs successfully
- Excellent communication and teamwork abilities
- Knowledge of front-end technology like JavaScript and HTML5
- Excellent problem-solving abilities
- Bachelor of Science in Computer Science, Engineering, or a related discipline
- Understanding of front-end technologies such as JavaScript, HTML5, and CSS3 is required
- Knowledge of some ORM (Object Relational Mapper) libraries
- Capable of combining many data sources and databases into a single system
- User authentication and authorization knowledge are required across many systems, servers, and environments
"""

# Extract key information from the job description
requirements_start = job_description.index("Requirements and Skills") + len("Requirements and Skills")
requirements_end = job_description.index("Bachelor of Science in Computer Science, Engineering, or a related discipline.")
responsibilities_start = job_description.index("Roles and Responsibilities:") + len("Roles and Responsibilities:")
responsibilities_end = job_description.index("Deploy data security and protection solutions.")

requirements = job_description[requirements_start:requirements_end].strip()
responsibilities = job_description[responsibilities_start:responsibilities_end].strip()

# Create a dictionary to store the summarized information
summary = {
    "Work Name": "Junior Python Engineer",
    "Location": "Not specified",
    "Experience": "Not specified",
    "Skills": requirements,
    "Post": responsibilities
}

# Create a pandas DataFrame from the summary dictionary
df = pd.DataFrame([summary])

# Print the pandas table
print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 46
#      44 # Extract key information from the job description
#      45 requirements_start = job_description.index("Requirements and Skills") + len("Requirements and Skills")
# ---> 46 requirements_end = job_description.index("Bachelor of Science in Computer Science, Engineering, or a related discipline.")
#      47 responsibilities_start = job_description.index("Roles and Responsibilities:") + len("Roles and Responsibilities:")
#      48 responsibilities_end = job_description.index("Deploy data security and protection solutions.")
#
# ValueError: substring not found
